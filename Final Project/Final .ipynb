# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %% [markdown]
# #### Problem 1

# %%
def divisors(n):
    if n < 1:
        return 0
    A = []
    for i in range(1,n + 1):
        if n % i == 0:
            A.append(i)
    return sum(A)

# %%
divisors(2)
# Out:
# 3

# %% [markdown]
# #### Problem 2

# %%
def stairs(n)

# %% [markdown]
# #### Problem 3

# %% [markdown]
# ##### Part A

# %%
800*(1 + .046/12)**(12*15)
# Out:
# 1592.8698377724127

# %% [markdown]
# ##### Part B

# %%
P = 800

# %%
for i in range(12*15):
    P =  P + P*(1 + .046/12) - P + 1.58

# %%
P
# Out:
# 2001.370167233411

# %% [markdown]
# Your miminum monthly deposit would have to be at least 1.58 per month to have at least $2,000 in this time frame

# %% [markdown]
# #### Problem 4

# %% [markdown]
# heads = 1<br/>
# tails = 0

# %%
def coin(n):
    count = 0
    coin = np.random.randint(2,size=n)
    for i in range(n - 2):
        if coin[i] == 1 and coin[i + 1] == 0 and coin[i + 2] == 1:
            return 1
        else:
            return 0

# %%
sum([coin(7) for i in range(10000)])/10000
# Out:
# 0.1199

# %% [markdown]
# The chance that this will happen at least once is 12 percent

# %% [markdown]
# ##### Problem 5

# %% [markdown]
# See Booklet

# %% [markdown]
# #### Problem 6

# %% [markdown]
# ##### Part A

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   OrderDate   Region      Rep     Item  Units  Unit Cost
# 0           0  2016-01-06  Central  Andrews   Pencil     14       1.29
# 1           1  2016-01-23     West  Sorvino      Pen     76       1.99
# 2           2  2016-02-09  Central   Kivell  Pen Set     42      23.95
# 3           3  2016-02-26     East   Howard      Pen     96       4.99
# 4           4  2016-03-15     East   Howard   Binder     29       1.99

# %%
df['Total'] = df['Units']*df['Unit Cost']

# %%
df.head()
# Out:
#    Unnamed: 0   OrderDate   Region      Rep     Item  Units  Unit Cost  \
# 0           0  2016-01-06  Central  Andrews   Pencil     14       1.29
# 1           1  2016-01-23     West  Sorvino      Pen     76       1.99
# 2           2  2016-02-09  Central   Kivell  Pen Set     42      23.95
# 3           3  2016-02-26     East   Howard      Pen     96       4.99
# 4           4  2016-03-15     East   Howard   Binder     29       1.99
#
#      Total
# 0    18.06
# 1   151.24
# 2  1005.90
# 3   479.04
# 4    57.71

# %% [markdown]
# ##### Part B

# %%
East = df[df['Region'] == 'East']

# %%
East[East['Units'] >= 80]
# Out:
#     Unnamed: 0   OrderDate Region     Rep    Item  Units  Unit Cost    Total
# 3            3  2016-02-26   East  Howard     Pen     96       4.99   479.04
# 27          27  2017-04-10   East  Parent  Binder     81      19.99  1619.19
# 36          36  2017-09-10   East   Jones  Pencil     95       1.99   189.05

# %% [markdown]
# There are three orders that are East region and have more than 80 units

# %% [markdown]
# #### Problem 7

# %%
boats = plt.imread('boats.png')

# %%
copy = boats.copy()

# %%
boats = boats[::-1]

# %%
boats = boats[:,::-1,:]

# %%
plt.imshow(boats)
