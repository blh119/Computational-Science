# %%
import numpy as np
import matplotlib.pyplot as plt 
import math

# %%
for i in range(1,11):
    print(i**2),
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
 a = [i**3 for i in range(1,11) if i % 2 == 0]

# %%
a
# Out:
# [8, 64, 216, 512, 1000]

# %%
a = np.arange(1,11)**2

# %%
b = np.arange(1,11)
b = (1/b)

# %%
plt.scatter(a,b)
plt.ylabel("1 / Numbers, n")
plt.xlabel("Numbers cubed, n")
plt.title("x^2 vs 1/x")
# Out:
# Text(0.5, 1.0, 'x^2 vs 1/x')

# %%
x = [1 + i *(4/1000) for i in range(1001)]
y = [math.log(i) + math.sin(i) for i in x]
plt.plot(x,y)
